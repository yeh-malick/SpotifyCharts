# %%
import pandas as pd
import seaborn as sns
import numpy as np


import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams ['figure.figsize'] = (12,8)

df = pd.read_csv(r'C:\Users\USER\Desktop\DAPortfolio\SpotifyStreams\OriginalDataSets\Spotify-2000-2019.csv')

# %%
df.head()
# Out:
#    Index                   Title             Artist            Top Genre  \
# 0      1                 Sunrise        Norah Jones      adult standards
# 1      2             Black Night        Deep Purple           album rock
# 2      3          Clint Eastwood           Gorillaz  alternative hip hop
# 3      4           The Pretender       Foo Fighters    alternative metal
# 4      5  Waitin' On A Sunny Day  Bruce Springsteen         classic rock
#
#    Year  Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  \
# 0  2004                     157      30            53            -14
# 1  2000                     135      79            50            -11
# 2  2001                     168      69            66             -9
# 3  2007                     173      96            43             -4
# 4  2002                     106      82            58             -5
#
#    Liveness  Valence Length (Duration)  Acousticness  Speechiness  Popularity
# ...

# %%
df.describe()
# Out:
#              Index         Year  Beats Per Minute (BPM)       Energy  \
# count  1994.000000  1994.000000             1994.000000  1994.000000
# mean    997.500000  1992.992979              120.215647    59.679539
# std     575.762538    16.116048               28.028096    22.154322
# min       1.000000  1956.000000               37.000000     3.000000
# 25%     499.250000  1979.000000               99.000000    42.000000
# 50%     997.500000  1993.000000              119.000000    61.000000
# 75%    1495.750000  2007.000000              136.000000    78.000000
# max    1994.000000  2019.000000              206.000000   100.000000
#
#        Danceability  Loudness (dB)     Liveness      Valence  Acousticness  \
# count   1994.000000    1994.000000  1994.000000  1994.000000   1994.000000
# mean      53.238215      -9.008526    19.012036    49.408726     28.858074
# std       15.351507       3.647876    16.727378    24.858212     29.011986
# ...

# %%
# Is there a correlation between songs' popularity and the level of lyrics
plt.scatter(x=df['Popularity'],y=df['Speechiness'])
plt.show()

# %%
sns.regplot(x='Popularity', y='Speechiness', data=df, scatter_kws={"color":"yellow"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='Popularity', ylabel='Speechiness'>

# %%
plt.scatter(x=df['Popularity'],y=df['Danceability'])
plt.show()

# %%
 sns.regplot(x='Popularity', y='Danceability', data=df, scatter_kws={"color":"yellow"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='Popularity', ylabel='Danceability'>

# %%
# Correlation matrix

df.corr()
# Out:
#                            Index      Year  Beats Per Minute (BPM)    Energy  \
# Index                   1.000000 -0.607910               -0.048918 -0.114307
# Year                   -0.607910  1.000000                0.012570  0.147235
# Beats Per Minute (BPM) -0.048918  0.012570                1.000000  0.156644
# Energy                 -0.114307  0.147235                0.156644  1.000000
# Danceability           -0.047156  0.077493               -0.140602  0.139616
# Loudness (dB)          -0.260179  0.343764                0.092927  0.735711
# Liveness               -0.027125  0.019017                0.016256  0.174118
# Valence                 0.063304 -0.166163                0.059653  0.405175
# Acousticness            0.057346 -0.132946               -0.122472 -0.665156
# Speechiness            -0.050991  0.054097                0.085598  0.205865
# Popularity              0.087442 -0.158962               -0.003181  0.103393
#
# ...

# %%
correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation matrix')
plt.xlabel('Spotify music')
plt.ylabel('Spotify music')
plt.show()

# %%
# The more acoustic a song feels, the less energetic the song
sns.regplot(x='Acousticness', y='Energy', data=df, scatter_kws={"color":"green"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='Acousticness', ylabel='Energy'>

# %%
#Songs' acousticness doesn't guarantee populairty
plt.scatter(x=df['Acousticness'], y=df['Popularity'])
plt.show()

# %%
sns.regplot(x='Energy', y='Popularity', data=df, scatter_kws={"color":"green"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='Energy', ylabel='Popularity'>

# %%
sns.regplot(x='Danceability', y='Popularity', data=df, scatter_kws={"color":"green"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='Danceability', ylabel='Popularity'>

# %%
# Top 10 Most popular genres
tg = df.groupby(['Top Genre']).mean()
tg.drop(columns=['Index','Year'])
tg1 = tg.sort_values(by=['Popularity'], ascending=False)

tg1.head(11)
# Out:
#                           Index    Year  Beats Per Minute (BPM)     Energy  \
# Top Genre
# celtic punk              1453.0  1988.0              119.000000  65.000000
# indie pop                 531.5  2012.5              128.000000  79.000000
# australian psych          617.0  2015.0              121.000000  81.000000
# ccm                       750.0  2018.0              148.000000  63.000000
# electro house             756.0  2018.0              180.000000  63.000000
# danish pop                679.0  2016.0              120.000000  47.000000
# atl hip hop               280.0  2003.0               80.000000  97.000000
# pop punk                 1821.0  1999.0              149.000000  90.000000
# electropop                671.0  2016.0              123.333333  58.333333
# la pop                    726.0  2017.0              174.000000  72.000000
# irish singer-songwriter   567.0  2014.0              129.000000  66.000000
#
# ...

# %%
# Influence of Acousticness on Energy & Popularity
sns.relplot(x="Acousticness", y="Energy", hue='Popularity', data=df)

# %%
# Influence of song positivity on Popularity
sns.relplot(x="Valence", y="Popularity", data=df)

# %%
group = df.groupby(['Artist',])\
.agg({'Title':'count', 'Popularity':'mean'})

# %%
singers_pop = group.sort_values(by=['Popularity'], ascending=False)

# %%
you = df.loc[df.Artist == "Youssou N'Dour"]
rih = df.loc[df.Artist == "Rihanna"]
ti = df.loc[df.Artist == "Tame Impala"]
bey = df.loc[df.Artist == "Beyoncé"]
artists= print(ti, you, rih, bey)
artists.drop(['Year','Valence Length (Duration)','Acousticness', 'Speechines', 'Beats Per Minute (BPM)','Energy', 'Danceability', 'Loudness (dB)','Liveness'], axis=1, inplace=True)



top4 = artists.groupby(['Artist'])\
.agg({'Title':'count', 'Popularity':'mean'})

top4.head()
# Out:
#      Index                       Title       Artist         Top Genre  Year  \
# 615    616               Let It Happen  Tame Impala  australian psych  2015
# 617    618  The Less I Know The Better  Tame Impala  australian psych  2015
#
#      Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  Liveness  \
# 615                     125      88            60             -6        11
# 617                     117      74            64             -4        17
#
#      Valence Length (Duration)  Acousticness  Speechiness  Popularity
# 615       58               468             0            4          76
# 617       79               216             1            3          85       Index                           Title          Artist Top Genre  Year  \
# 29     30  7 Seconds (feat. Neneh Cherry)  Youssou N'Dour   afropop  2004
#
#     Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  Liveness  \
# ...

# %%
# Influence of song positivity on Popularity
sns.relplot(x="Beats Per Minute (BPM)", y="Valence", data=df)

# %%
# Influence of song positivity on Popularity
sns.relplot(x='Speechiness', y='Valence', data=df, hue='Energy')

# %%
tg.corr()
correlation_matrix = tg.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation matrix2')
plt.xlabel('Spotify music')
plt.ylabel('Spotify music')
plt.show()

# %%
# Linear predictive model 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
train = df.drop(['Popularity','Title'], axis=1)
test = df['Popularity']

# %%
X_train, X_test, y_train, y_test = train_test_split(train, test, test_size=0.3, random_state=2)

# %%
regr = LinearRegression()

# %%
print(regr)
# Out:
# LinearRegression()
